# %%
import pandas as pd

# %% [markdown]
# # Sacramento report

# %%
df = pd.read_csv('results_new.csv', index_col=0) 
answer = 100 * df.mean()/df.mean()['node.my_sac.ds_1']
pd.DataFrame({'Split [%]': answer}).round(1)
# Out:
#                    Split [%]
# node.my_sac.ds_1       100.0
# node.my_sac.flosf        2.0
# node.my_sac.flobf       90.6
# node.my_sac.floin        7.4

# %%
df[['node.my_sac.ds_1']].plot()
# Out:
# <Axes: xlabel='Time'>

# %%
df[['node.my_sac.ds_1']].describe()
# Out:
#        node.my_sac.ds_1
# count      45530.000000
# mean         390.668157
# std          905.368945
# min            0.000000
# 25%           90.308168
# 50%          176.490037
# 75%          390.323692
# max        54346.695901
